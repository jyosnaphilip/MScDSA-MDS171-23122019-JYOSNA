# %%
import pandas as pd

# %%
df=pd.read_csv("airports .csv")

# %%
df.index
# Out:
# RangeIndex(start=0, stop=76367, step=1)

# %%
df.head()
# Out:
#        id ident           type                  name  latitude_deg  \
# 0    6523   00A       heliport     Total RF Heliport     40.070985
# 1  323361  00AA  small_airport  Aero B Ranch Airport     38.704022
# 2    6524  00AK  small_airport          Lowell Field     59.947733
# 3    6525  00AL  small_airport          Epps Airpark     34.864799
# 4  506791  00AN  small_airport  Katmai Lodge Airport     59.093287
#
#    longitude_deg  elevation_ft continent iso_country iso_region  municipality  \
# 0     -74.933689          11.0       NaN          US      US-PA      Bensalem
# 1    -101.473911        3435.0       NaN          US      US-KS         Leoti
# 2    -151.692524         450.0       NaN          US      US-AK  Anchor Point
# 3     -86.770302         820.0       NaN          US      US-AL       Harvest
# 4    -156.456699          80.0       NaN          US      US-AK   King Salmon
#
#   scheduled_service gps_code iata_code local_code  \
# ...

# %%
df.set_index("name",inplace=True)

# %%
df.head()
# Out:
#                           id ident           type  latitude_deg  \
# name
# Total RF Heliport       6523   00A       heliport     40.070985
# Aero B Ranch Airport  323361  00AA  small_airport     38.704022
# Lowell Field            6524  00AK  small_airport     59.947733
# Epps Airpark            6525  00AL  small_airport     34.864799
# Katmai Lodge Airport  506791  00AN  small_airport     59.093287
#
#                       longitude_deg  elevation_ft continent iso_country  \
# name
# Total RF Heliport        -74.933689          11.0       NaN          US
# Aero B Ranch Airport    -101.473911        3435.0       NaN          US
# Lowell Field            -151.692524         450.0       NaN          US
# Epps Airpark             -86.770302         820.0       NaN          US
# Katmai Lodge Airport    -156.456699          80.0       NaN          US
#
#                      iso_region  municipality scheduled_service gps_code  \
# name
# ...

# %%
print(df.shape)
# Out:
# (76367, 17)

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#                    name      id ident           type  latitude_deg  \
# 0     Total RF Heliport    6523   00A       heliport     40.070985
# 1  Aero B Ranch Airport  323361  00AA  small_airport     38.704022
# 2          Lowell Field    6524  00AK  small_airport     59.947733
# 3          Epps Airpark    6525  00AL  small_airport     34.864799
# 4  Katmai Lodge Airport  506791  00AN  small_airport     59.093287
#
#    longitude_deg  elevation_ft continent iso_country iso_region  municipality  \
# 0     -74.933689          11.0       NaN          US      US-PA      Bensalem
# 1    -101.473911        3435.0       NaN          US      US-KS         Leoti
# 2    -151.692524         450.0       NaN          US      US-AK  Anchor Point
# 3     -86.770302         820.0       NaN          US      US-AL       Harvest
# 4    -156.456699          80.0       NaN          US      US-AK   King Salmon
#
#   scheduled_service gps_code iata_code local_code  \
# ...

# %%
df.set_index(["name","id"],inplace=True)

# %%
df.head()
# Out:
#                             ident           type  latitude_deg  longitude_deg  \
# name                 id
# Total RF Heliport    6523     00A       heliport     40.070985     -74.933689
# Aero B Ranch Airport 323361  00AA  small_airport     38.704022    -101.473911
# Lowell Field         6524    00AK  small_airport     59.947733    -151.692524
# Epps Airpark         6525    00AL  small_airport     34.864799     -86.770302
# Katmai Lodge Airport 506791  00AN  small_airport     59.093287    -156.456699
#
#                              elevation_ft continent iso_country iso_region  \
# name                 id
# Total RF Heliport    6523            11.0       NaN          US      US-PA
# Aero B Ranch Airport 323361        3435.0       NaN          US      US-KS
# Lowell Field         6524           450.0       NaN          US      US-AK
# Epps Airpark         6525           820.0       NaN          US      US-AL
# ...

# %%
df.reset_index(level=["name"],inplace=True)

# %%
df.head(2)
df.index
# Out:
# Index(['Total RF Heliport', 'Aero B Ranch Airport', 'Lowell Field',
#        'Epps Airpark', 'Katmai Lodge Airport',
#        'Newport Hospital & Clinic Heliport', 'Fulton Airport',
#        'Cordes Airport', 'Goldstone (GTS) Airport', 'Williams Ag Airport',
#        ...
#        'Shenyang Taoxian International Airport', 'Mt Logan Airstrip',
#        'Yanji Chaoyangchuan Airport', 'Yingkou Lanqi Airport',
#        'Shenyang Dongta Airport', 'Sealand Helipad',
#        'Glorioso Islands Airstrip', 'Fainting Goat Airport',
#        'Scandium City Heliport', 'Satsuma Iōjima Airport'],
#       dtype='object', name='name', length=76367)

# %%
print(df["type"]=="heliport")
# Out:
# name
# Total RF Heliport             True
# Aero B Ranch Airport         False
# Lowell Field                 False
# Epps Airpark                 False
# Katmai Lodge Airport         False
#                              ...
# Sealand Helipad               True
# Glorioso Islands Airstrip    False
# Fainting Goat Airport        False
# Scandium City Heliport       False
# Satsuma Iōjima Airport       False
# Name: type, Length: 76367, dtype: bool

# %%
one_row=df.loc["Total RF Heliport"] #should have index inside
print(one_row)
more_than_one_row=df.loc["Total RF Heliport"]
secon_row=df.loc["Sealand Helipad"]
print(more_than_one_row,"\n",secon_row)
# Out:
# id                                                                6523
# ident                                                              00A
# type                                                          heliport
# latitude_deg                                                 40.070985
# longitude_deg                                               -74.933689
# elevation_ft                                                      11.0
# continent                                                          NaN
# iso_country                                                         US
# iso_region                                                       US-PA
# municipality                                                  Bensalem
# scheduled_service                                                   no
# gps_code                                                          K00A
# iata_code                                                          NaN
# ...

# %%
more_than_one_row=df.loc[["Total RF Heliport","Sealand Helipad"]]
more_than_one_row
# Out:
#                       id    ident      type  latitude_deg  longitude_deg  \
# name
# Total RF Heliport   6523      00A  heliport     40.070985     -74.933689
# Sealand Helipad    46378  ZZ-0001  heliport     51.894444       1.482500
#
#                    elevation_ft continent iso_country iso_region municipality  \
# name
# Total RF Heliport          11.0       NaN          US      US-PA     Bensalem
# Sealand Helipad            40.0        EU          GB     GB-ENG      Sealand
#
#                   scheduled_service gps_code iata_code local_code  \
# name
# Total RF Heliport                no     K00A       NaN        00A
# Sealand Helipad                  no      NaN       NaN        NaN
#
#                                                            home_link  \
# name
# Total RF Heliport  https://www.penndot.pa.gov/TravelInPA/airports...
# Sealand Helipad                           http://www.sealandgov.org/
#
# ...

# %%
#to get all airports in same country
df.set_index(["iso_country"],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32164\2616490461.py in ?()
#       1 #to get all airports in same country
# ----> 2 df.set_index(["iso_country"],inplace=True)
#       3 df.index
#
# c:\Users\jyosn\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5869                     if not found:
#    5870                         missing.append(col)
#    5871
#    5872         if missing:
# -> 5873             raise KeyError(f"None of {missing} are in the columns")
#    5874
#    5875         if inplace:
#    5876             frame = self
#
# KeyError: "None of ['iso_country'] are in the columns"

# %%
df.index
# Out:
# Index(['US', 'US', 'US', 'US', 'US', 'US', 'US', 'US', 'US', 'US',
#        ...
#        'CN', 'CA', 'CN', 'CN', 'CN', 'GB', 'TF', 'US', 'CA', 'JP'],
#       dtype='object', name='iso_country', length=76367)

# %%
df.loc[["IN"]]
# Out:
#                 id    ident           type  latitude_deg  longitude_deg  \
# iso_country
# IN           35129  IN-0001       heliport     35.194275      77.213051
# IN           35130  IN-0002       heliport     27.588732      91.877439
# IN           42716  IN-0003  small_airport     35.396467      77.928965
# IN           42717  IN-0004       heliport     34.129295      77.537205
# IN           42721  IN-0005         closed      8.970609      77.816847
# ...            ...      ...            ...           ...            ...
# IN           26629     VOTV  large_airport      8.482120      76.920097
# IN           26630     VOTX  small_airport     12.907200      80.121902
# IN           32592     VOVR  small_airport     12.908800      79.066803
# IN           32647     VOWA  small_airport     17.914400      79.602203
# IN           26631     VOYK  small_airport     13.135500      77.606003
#
#              elevation_ft continent iso_region        municipality  \
# iso_country
# ...
