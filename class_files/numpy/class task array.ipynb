# %% [markdown]
# load a csv, set new column names

# %%
import pandas as pd

# %%
file=pd.read_csv("AAPL.csv",)

file.columns=["Date","Open","H","L","C","Adj Close","Vol"]
file.head()
# Out:
#          Date        Open           H           L           C   Adj Close  \
# 0  29/09/2014  100.589996  100.690002   98.040001   99.620003   93.514290
# 1  06/10/2014   99.949997  102.379997   98.309998  100.730003   94.556244
# 2  13/10/2014  101.330002  101.779999   95.180000   97.669998   91.683792
# 3  20/10/2014   98.320000  105.489998   98.220001  105.220001   98.771042
# 4  27/10/2014  104.849998  108.040001  104.699997  108.000000  101.380676
#
#          Vol
# 0  142718700
# 1  280258200
# 2  358539800
# 3  358532900
# 4  220230600

# %%
file.rename(columns={"Open":"Opening","H":"Highest"},inplace=True)

# %%
file.head(2)
# Out:
#          Date     Opening     Highest          L           C  Adj Close  \
# 0  29/09/2014  100.589996  100.690002  98.040001   99.620003  93.514290
# 1  06/10/2014   99.949997  102.379997  98.309998  100.730003  94.556244
#
#          Vol
# 0  142718700
# 1  280258200

# %%
file.set_index("Date",inplace=True)

# %%
file.head(2)
# Out:
#                Opening     Highest          L           C  Adj Close  \
# Date
# 29/09/2014  100.589996  100.690002  98.040001   99.620003  93.514290
# 06/10/2014   99.949997  102.379997  98.309998  100.730003  94.556244
#
#                   Vol
# Date
# 29/09/2014  142718700
# 06/10/2014  280258200

# %%
file["difference"]=file["Highest"]-file["L"]

# %%
file.head(2)
# Out:
#                Opening     Highest          L           C  Adj Close  \
# Date
# 29/09/2014  100.589996  100.690002  98.040001   99.620003  93.514290
# 06/10/2014   99.949997  102.379997  98.309998  100.730003  94.556244
#
#                   Vol  difference
# Date
# 29/09/2014  142718700    2.650001
# 06/10/2014  280258200    4.069999

# %%
file1=pd.read_csv("AAPL.csv")
print(file1.info())
file2=pd.read_csv("Book1.csv")
print(file2.info())
file2.columns=file1.columns
newfile=pd.merge(file1,file2,how="outer")
newfile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       169 non-null    object
#  1   Open       169 non-null    float64
#  2   High       169 non-null    float64
#  3   Low        169 non-null    float64
#  4   Close      169 non-null    float64
#  5   Adj Close  169 non-null    float64
#  6   Volume     169 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 9.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   25/12/2017  14 non-null     object
#  1   170.800003  14 non-null     float64
#  2   171.850006  14 non-null     float64
#  3   169.220001  14 non-null     float64
#  4   169.229996  14 non-null     float64
# ...

# %%
file1.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  29/09/2014  100.589996  100.690002   98.040001   99.620003   93.514290
# 1  06/10/2014   99.949997  102.379997   98.309998  100.730003   94.556244
# 2  13/10/2014  101.330002  101.779999   95.180000   97.669998   91.683792
# 3  20/10/2014   98.320000  105.489998   98.220001  105.220001   98.771042
# 4  27/10/2014  104.849998  108.040001  104.699997  108.000000  101.380676
#
#       Volume
# 0  142718700
# 1  280258200
# 2  358539800
# 3  358532900
# 4  220230600

# %%
file2.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  01/01/2018  170.160004  175.369995  169.259995  175.000000  174.289398
# 1  08/01/2018  174.350006  177.360001  173.000000  177.089996  176.370911
# 2  15/01/2018  177.899994  180.100006  175.070007  178.460007  177.735352
# 3  22/01/2018  177.300003  179.440002  170.059998  171.509995  170.813568
# 4  29/01/2018  170.160004  170.160004  160.100006  160.500000  159.848282
#
#       Volume
# 0  101168400
# 1  110197500
# 2  127571200
# 3  191574800
# 4  262992100

# %%
file3=pd.read_csv("AAPL - Copy.csv")
print(file3.columns)
file4=pd.read_csv("Book2.csv")
print(file4.columns)
pd.merge(file3,file4,how="inner",on="Date")
# Out:
# Index(['Date', 'Open', 'High', 'Low'], dtype='object')
# Index(['Date', 'Close', 'Adj Close', 'Volume'], dtype='object')
#            Date        Open        High         Low       Close   Adj Close  \
# 0    29/09/2014  100.589996  100.690002   98.040001   99.620003   93.514290
# 1    06/10/2014   99.949997  102.379997   98.309998  100.730003   94.556244
# 2    13/10/2014  101.330002  101.779999   95.180000   97.669998   91.683792
# 3    20/10/2014   98.320000  105.489998   98.220001  105.220001   98.771042
# 4    27/10/2014  104.849998  108.040001  104.699997  108.000000  101.380676
# ..          ...         ...         ...         ...         ...         ...
# 164  20/11/2017  170.289993  175.500000  169.559998  174.970001  174.259521
# 165  27/11/2017  175.050003  175.080002  167.160004  171.050003  170.355438
# 166  04/12/2017  172.479996  172.619995  166.460007  169.369995  168.682251
# 167  11/12/2017  169.199997  174.169998  168.789993  173.970001  173.263580
# ...
